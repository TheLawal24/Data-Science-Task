# %% [markdown]
# 1. Obtain a list of the top-20 "Text Classification" and top-20 "Text Generation" models on https://huggingface.co/, ranked based on popularity

# %%
#Import Libraries and authorize Token (API)
import requests #Importing the requests Library
def get_models_from_api(parameter, endpoint_value, search_value, limit_value): #Function definition and parameters
        # Construct the API request using the requests library

         # Make an HTTP GET request to the Hugging Face Model Hub API
  response = requests.get( #API Request
    "https://huggingface.co/api/"+endpoint_value, #Specific API from Hugging face EndPoint
    params={"filter":  parameter,"sort":"downloads","direction":"-1","limit":limit_value,"full":"True","config":"True","search":search_value},
    headers={"Authorization":"Bearer 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"} #API
  )
    # Return the JSON response from the API
  return response.json(); #Json Response

# %%
 #Obtaining text classification models from the Hugging Face Model Hub using API/Token
textClassifications = get_models_from_api('text-classification', 'models', None, 20) #Text Classification Models Retrieval

  # Get text generation models from the Hugging Face Model Hub API
textGenerations = get_models_from_api('text-generation', 'models', None, 20) #Text Generation Models Retrieval

  # Get information about a specific model from the Hugging Face Model Hub API (bigscience/bloom-560m in this case)
spaceV = get_models_from_api(None, 'spaces', 'bigscience/bloom-560m', None) #Specific Model Retrieval

  # Extract only the 'id' field from each entry for text classification models
textClassificationWithId = [{'id': entry['id']} for entry in textClassifications] #Data Transformation - Extract 'id' Field

  # Extract only the 'id' field from each entry for text generation models
textGenerationWithId = [{'id': entry['id']} for entry in textClassifications] #Data Extraction - Model IDs

  # Extract a list of model IDs for text classification models
textClassification = [entry['id'] for entry in textClassifications]

  # Extract a list of model IDs for text generation models
textGeneration = [entry['id'] for entry in textGenerations]

#Print Statements

#Obtaining text classification Models
print(textClassification)

# Print the list of model IDs for text generation
print(textGeneration)

# Print the details of text generation models
print(textGenerations)

# Print the length of the spaceV response (number of models or information entries retrieved)
print(len(spaceV))
# Out:
# ['cardiffnlp/twitter-roberta-base-sentiment-latest', 'cardiffnlp/twitter-roberta-base-irony', 'lxyuan/distilbert-base-multilingual-cased-sentiments-student', 'SamLowe/roberta-base-go_emotions', 'mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis', 'marieke93/MiniLM-evidence-types', 'Ashishkr/query_wellformedness_score', 'distilbert/distilbert-base-uncased-finetuned-sst-2-english', 'smilegate-ai/kor_unsmile', 'facebook/bart-large-mnli', 'MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli', 'laiyer/deberta-v3-base-prompt-injection', 'cardiffnlp/twitter-roberta-base-sentiment', 'j-hartmann/emotion-english-distilroberta-base', 'nlptown/bert-base-multilingual-uncased-sentiment', 'vikp/column_detector', 'CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment', 'cross-encoder/ms-marco-MiniLM-L-6-v2', 'padmajabfrl/Gender-Classification', 'cardiffnlp/twitter-xlm-roberta-base-sentiment']
# ...

# %% [markdown]
# 2. Obtain and compare the number of ML apps ("spaces") for each "Text Classification" and "Text Generation" model obtained in step 1

# %%
 # Comparing the Number of ML apps for Text Generation models
for value in textGeneration: #Iteration Over Text Generation Models

  # Use get_models_from_api to retrieve information about a specific model (identified by value) from the Hugging Face Model Hub API
   spaceValue = get_models_from_api(None, 'spaces', value, None) #Model Information Retrieval

   # Print the Model ID and the length of the spaceValue response (number of models or information entries retrieved)
   print(f"{value}, {len(spaceValue)}") #Print Statement
# Out:
# openai-community/gpt2, 1
# baffo32/decapoda-research-llama-7B-hf, 0
# distilbert/distilgpt2, 0
# facebook/opt-2.7b, 0
# mistralai/Mixtral-8x7B-Instruct-v0.1, 19
# bigscience/bloom-560m, 22
# tiiuae/falcon-40b-instruct, 0
# meta-llama/Llama-2-7b-chat-hf, 268
# TheBloke/Mixtral-8x7B-Instruct-v0.1-GPTQ, 0
# mistralai/Mistral-7B-v0.1, 184
# teknium/OpenHermes-2-Mistral-7B, 18
# meta-llama/Llama-2-7b-hf, 322
# h2oai/h2ogpt-4096-llama2-7b-chat, 0
# microsoft/phi-2, 23
# lmsys/vicuna-7b-v1.5, 0
# openai-community/gpt2-xl, 0
# facebook/opt-125m, 0
# openai-community/gpt2-large, 1
# microsoft/git-base, 5
# TheBloke/vicuna-7B-v1.3-GPTQ, 0

# %%
for value in textClassification:
  spaceValue = get_models_from_api(None, 'spaces', value, None)
  print(f"{value}, {len(spaceValue)}")
# Out:
# cardiffnlp/twitter-roberta-base-sentiment-latest, 19
# cardiffnlp/twitter-roberta-base-irony, 2
# lxyuan/distilbert-base-multilingual-cased-sentiments-student, 0
# SamLowe/roberta-base-go_emotions, 10
# mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis, 5
# marieke93/MiniLM-evidence-types, 0
# Ashishkr/query_wellformedness_score, 0
# distilbert/distilbert-base-uncased-finetuned-sst-2-english, 16
# smilegate-ai/kor_unsmile, 1
# facebook/bart-large-mnli, 29
# MoritzLaurer/DeBERTa-v3-base-mnli-fever-anli, 3
# laiyer/deberta-v3-base-prompt-injection, 1
# cardiffnlp/twitter-roberta-base-sentiment, 25
# j-hartmann/emotion-english-distilroberta-base, 7
# nlptown/bert-base-multilingual-uncased-sentiment, 5
# vikp/column_detector, 0
# CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment, 2
# cross-encoder/ms-marco-MiniLM-L-6-v2, 0
# padmajabfrl/Gender-Classification, 0
# cardiffnlp/twitter-xlm-roberta-base-sentiment, 4

# %%
 #Retrieving Information on Hugging Face Model API

# Importing the requests library for making HTTP requests
import requests #library import

# Making an HTTP GET request to the Hugging Face Model Hub API to retrieve information about a specific model
response = requests.get( #API Request
  "https://huggingface.co/api/spaces/Amrrs/image-caption-with-vit-gpt2", #API Request HTTPS
  params={},
  headers={"Authorization":"Bearer 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"} #API header and Generated Token
)

# Printing the JSON content of the API response
print(response.json()) #API Response
# Out:
# {'_id': '621ffddf36468d709f184407', 'id': 'Amrrs/image-caption-with-vit-gpt2', 'author': 'Amrrs', 'sha': '4f0b88976d4e38223da10033575151983d1aac8d', 'lastModified': '2022-01-29T10:26:28.000Z', 'private': False, 'cardData': {'title': 'Image Caption With Vit Gpt2', 'emoji': '👀', 'colorFrom': 'pink', 'colorTo': 'pink', 'sdk': 'gradio', 'app_file': 'app.py', 'pinned': False, 'license': 'mit'}, 'gated': False, 'disabled': False, 'host': 'https://amrrs-image-caption-with-vit-gpt2.hf.space', 'subdomain': 'amrrs-image-caption-with-vit-gpt2', 'tags': ['gradio'], 'likes': 5, 'models': ['distilgpt2', 'google/vit-base-patch16-224-in21k', 'sachin/vit2distilgpt2'], 'sdk': 'gradio', 'runtime': {'stage': 'BUILD_ERROR', 'hardware': {'current': None, 'requested': 'cpu-basic'}, 'storage': {'current': None, 'requested': None}, 'gcTimeout': 86400, 'errorMessage': 'Unexpected build error', 'replicas': {'current': 1, 'requested': 1}}, 'siblings': [{'rfilename': '.gitattributes'}, {'rfilename': 'README.md'}
# ...

# %%
#Further Comparison Due to flunctuation in Model trends
from bs4 import BeautifulSoup
import requests

def get_model(model_type='text-classification', sort='downloads', limit=20): #Functions

  text_classification = []
  text_generation = []
  url = 'https://huggingface.co/models?pipeline_tag='+model_type+'&sort='+sort
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'lxml')
  models = soup.find_all('article', class_='overview-card-wrapper group/repo')
  c = 0
  for model in models:
    c = c+1
    model_name = model.find('h4', class_='text-md truncate font-mono text-black dark:group-hover/repo:text-yellow-500 group-hover/repo:text-indigo-600 text-smd').text

    if model_type == 'text-classification':
      text_classification.append(model_name)
    elif model_type == 'text-generation':
      text_generation.append(model_name)
  if model_type == 'text-classification':
    return text_classification[:limit]
  elif model_type == 'text-generation':
    return text_generation[:limit]

# %%
#Definition
text_classification = get_model(model_type='text-classification')

# %%
text_classification #Prompt
# Out:
# ['cardiffnlp/twitter-roberta-base-sentiment-latest',
#  'cardiffnlp/twitter-roberta-base-irony',
#  'lxyuan/distilbert-base-multilingual-cased-sentiments-student',
#  'SamLowe/roberta-base-go_emotions',
#  'mrm8488/distilroberta-finetuned-financial-news-sentiment-analysis',
#  'marieke93/MiniLM-evidence-types',
#  'Ashishkr/query_wellformedness_score',
#  'distilbert/distilbert-base-uncased-finetuned-sst-2-english',
#  'smilegate-ai/kor_unsmile',
#  'laiyer/deberta-v3-base-prompt-injection',
#  'cardiffnlp/twitter-roberta-base-sentiment',
#  'j-hartmann/emotion-english-distilroberta-base',
#  'nlptown/bert-base-multilingual-uncased-sentiment',
#  'vikp/column_detector',
#  'CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment',
#  'cross-encoder/ms-marco-MiniLM-L-6-v2',
#  'padmajabfrl/Gender-Classification',
#  'cardiffnlp/twitter-xlm-roberta-base-sentiment',
#  'cross-encoder/ms-marco-MiniLM-L-4-v2',
#  'cross-encoder/ms-marco-TinyBERT-L-2-v2']

# %%
#Definition
text_generation = get_model(model_type='text-generation')

# %%
text_generation #Prompt
# Out:
# ['openai-community/gpt2',
#  'baffo32/decapoda-research-llama-7B-hf',
#  'distilbert/distilgpt2',
#  'facebook/opt-2.7b',
#  'mistralai/Mixtral-8x7B-Instruct-v0.1',
#  'bigscience/bloom-560m',
#  'tiiuae/falcon-40b-instruct',
#  'meta-llama/Llama-2-7b-chat-hf',
#  'TheBloke/Mixtral-8x7B-Instruct-v0.1-GPTQ',
#  'mistralai/Mistral-7B-v0.1',
#  'teknium/OpenHermes-2-Mistral-7B',
#  'meta-llama/Llama-2-7b-hf',
#  'h2oai/h2ogpt-4096-llama2-7b-chat',
#  'HuggingFaceM4/tiny-random-LlamaForCausalLM',
#  'microsoft/phi-2',
#  'lmsys/vicuna-7b-v1.5',
#  'openai-community/gpt2-xl',
#  'facebook/opt-125m',
#  'openai-community/gpt2-large',
#  'TheBloke/vicuna-7B-v1.3-GPTQ']

# %%
#DataFrame Iluustration of comparisons
import pandas as pd

# %%
text_classification_df = pd.DataFrame(text_classification)
text_generation_df = pd.DataFrame(text_generation)

# %%
text_classification_df
# Out:
#                                                     0
# 0    cardiffnlp/twitter-roberta-base-sentiment-latest
# 1               cardiffnlp/twitter-roberta-base-irony
# 2   lxyuan/distilbert-base-multilingual-cased-sent...
# 3                    SamLowe/roberta-base-go_emotions
# 4   mrm8488/distilroberta-finetuned-financial-news...
# 5                     marieke93/MiniLM-evidence-types
# 6                 Ashishkr/query_wellformedness_score
# 7   distilbert/distilbert-base-uncased-finetuned-s...
# 8                            smilegate-ai/kor_unsmile
# 9             laiyer/deberta-v3-base-prompt-injection
# 10          cardiffnlp/twitter-roberta-base-sentiment
# 11      j-hartmann/emotion-english-distilroberta-base
# 12   nlptown/bert-base-multilingual-uncased-sentiment
# 13                               vikp/column_detector
# 14  CAMeL-Lab/bert-base-arabic-camelbert-da-sentiment
# 15               cross-encoder/ms-marco-MiniLM-L-6-v2
# ...

# %%
text_classification_spaces = []
for model in text_classification:
  url = 'https://huggingface.co/'+model
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'lxml') #Web Scraping
  number_of_spaces = soup.find('span', class_='ml-3 font-normal text-gray-400')
  try:
    text_classification_spaces.append(number_of_spaces.text)
  except AttributeError:
    text_classification_spaces.append(0)
print(text_classification_spaces)
# Out:
# ['70', '2', '15', '43', '27', 0, 0, '219', '14', '2', '65', '55', '63', 0, '2', '71', '2', '18', '3', '8']

# %%
text_generation_spaces = []
for model in text_generation:
  url = 'https://huggingface.co/'+model
  response = requests.get(url)
  soup = BeautifulSoup(response.text, 'lxml')
  number_of_spaces = soup.find('span', class_='ml-3 font-normal text-gray-400')
  try:
    text_generation_spaces.append(number_of_spaces.text)
  except AttributeError:
    text_generation_spaces.append(0)
print(text_generation_spaces)
# Out:
# ['1247', 0, '121', '24', '355', '87', '64', '642', '1', '266', '3', '116', '9', 0, '110', '46', '69', '88', '111', 0]

# %%
#Basic Comparison between Text
text_classification_spaces_arr = np.array(text_classification_spaces, dtype=np.int32)
text_generation_spaces_arr = np.array(text_generation_spaces, dtype=np.int32)

text_classification_spaces_arr
# Out:
# array([ 70,   2,  15,  43,  27,   0,   0, 219,  14,   2,  65,  55,  63,
#          0,   2,  71,   2,  18,   3,   8], dtype=int32)

# %%
total_text_classification_spaces = np.array(text_classification_spaces_arr, dtype=np.int32).sum()
total_text_generation_spaces = np.array(text_generation_spaces_arr, dtype=np.int32).sum()

print('Total text Classification Spaces:', total_text_classification_spaces)
print('Total text Generation Spaces:', total_text_generation_spaces)
# Out:
# Total text Classification Spaces: 679
# Total text Generation Spaces: 3359

# %% [markdown]
# 3. Obtain and compare the source code size of the ML apps ("spaces") obtained in step 2

# %%
# Here got me a bit confused. From the HINT you gave, afterning navigating the spaces and files.. i merely saw raw files&sizes.
#Source Code Size Was Manually Computed.
#Maximum of 20 source files obtain and minimum of 5.

#Uploaded Excel because i keep getting error with CSV of "Source Files" of the Obtained Number of ML apps each  for Text CLassification

pd.read_excel('/content/Text_Classification.xlsx')
# Out:
#                                         CARDIFF NLP  \
# 0                                               NaN
# 1                                               NaN
# 2                                               NaN
# 3                                               NaN
# 4                                               NaN
# 5                                               NaN
# 6                                      smilegate-ai
# 7                                               NaN
# 8                                               NaN
# 9                                            lxyuan
# 10                                              NaN
# 11  distilbert-base-uncased-finetuned-sst-2-english
# 12                                              NaN
# 13                                              NaN
# 14                                              NaN
# 15                                              NaN
# 16                                              NaN
# ...

# %%
# Comparison of Obtained Number of ML apps (Names and sizes) for each for Text Generation (Excel)
#Maximum of 20 source files obtain and minimum of 5.
pd.read_excel('/content/Text_Generation.xlsx')
# Out:
#         GPT2/openai-community                              Unnamed: 1  \
# 0                         NaN                                APP Name
# 1                         NaN                             TamilselviK
# 2                         NaN                                   Amrrs
# 3                         NaN                                    GPT2
# 4                         NaN                               GPT2Space
# 5                         NaN                           GPT2Tokenizer
# 6                         NaN                                     Try
# 7                         NaN                           GPT2 Rap Song
# 8                         NaN                               GPT2 Home
# 9                         NaN                          GPT2 Story Gen
# 10                        NaN                               AI MsgBot
# 11                        NaN                               Test GPT2
# ...

# %% [markdown]
# 4. Analyze your results of the previous steps in order to confirm or reject the claim 'it is easier to develop ML applications using "Text Classification" models than applications using "Text Generation" models'

# %%
# Analyzing the total file sizes of ML applications for Text Classification and Text Generation models

if total_text_classification_spaces > total_text_generation_spaces: # Confirm if the total file size for Text Classification models is greater than that for Text Generation models
    print("There are more ML apps for Text Classification models.")

    # Confirm if the total file size for Text Generation models is greater than that for Text Classification models
elif total_text_classification_spaces < total_text_generation_spaces:
    print("There are more ML apps for Text Generation models.")

    # If the total file sizes are equal for both Text Classification and Text Generation models
else:
    print("The number of ML apps is the same for both Text Classification and Text Generation models.")
# Out:
# There are more ML apps for Text Generation models.

# %% [markdown]
# Statistical Analysis with mean, median, and Standard Deviation (S.D)

# %%
# Calculate the median of the array containing spaces for text classification
median_text_classification_spaces = np.median(text_classification_spaces_arr)

# Calculate the median of the array containing spaces for text generation
median_text_generation_spaces = np.median(text_generation_spaces_arr)

# Calculate the standard deviation of the array containing spaces for text classification
std_text_classification_spaces = np.std(text_classification_spaces_arr)

# Calculate the standard deviation of the array containing spaces for text generation
std_text_generation_spaces = np.std(text_generation_spaces_arr)

# Print the mean spaces for text classification
print("Mean Text Classification Spaces:", mean_text_classification_spaces)

# Print the mean spaces for text generation
print("Mean Text Generation Spaces:", mean_text_generation_spaces)

# Print the median spaces for text classification
print("Median Text Classification Spaces:", median_text_classification_spaces)

# Print the median spaces for text generation
print("Median Text Generation Spaces:", median_text_generation_spaces)

# Print the standard deviation of spaces for text classification
print("Standard Deviation Text Classification Spaces:", std_text_classification_spaces)

# Print the standard deviation of spaces for text generation
print("Standard Deviation Text Generation Spaces:", std_text_generation_spaces)
# Out:
# Mean Text Classification Spaces: 33.95
# Mean Text Generation Spaces: 167.95
# Median Text Classification Spaces: 14.5
# Median Text Generation Spaces: 78.0
# Standard Deviation Text Classification Spaces: 49.73979794892617
# Standard Deviation Text Generation Spaces: 289.76550433065694

# %%
# Importing library for plotting
import matplotlib.pyplot as plt

# Fig specification size (10 inches wide and 6 inches tall)
plt.figure(figsize=(10, 6))

# Histogram distribution of spaces in text classification data
plt.hist(text_classification_spaces_arr, bins=20, alpha=0.5, label='Text Classification')

plt.hist(text_generation_spaces_arr, bins=20, alpha=0.5, label='Text Generation')

# Label to the x-axis
plt.xlabel('Number of Spaces')

# Label to the y-axis
plt.ylabel('Frequency')

# Title to the plot
plt.title('Distribution of Spaces')

# Adding a legend to distinguish between text classification and text generation
plt.legend()

# Displaying the plot
plt.show()

# %%
# Import the necessary library for plotting
plt.figure(figsize=(10, 6)) #figure size


plt.boxplot([text_classification_spaces_arr, text_generation_spaces_arr], labels=['Text Classification', 'Text Generation'])

plt.xlabel('Model Type')
plt.ylabel('Number of Spaces')
plt.title('Box Plot of Spaces for Text Classification and Text Generation Models')
plt.show()

# %%
#Statistical Analysis Visualization #Histogram
import statistics
import matplotlib.pyplot as plt
import numpy as np

# Text Generation Data from Source Code size (CSV )
file_sizes_generation = [
    1.85, 144.405, 19.88, 7.477, 3.08, 18.404, 3.72, 7.533, 1.775, 3.75, 2.45, 1.18, 3.41, 69.303,
    19.37, 513985.97, 5.65, 4.797, 1023.96, 1034.65, 24.66, 2.67, 6.85, 4.778,
    3.27, 29163.75, 7.366, 5.764, 134.2, 3.267, 1.83, 1.838, 1.785, 1.8, 1.842, 1.86, 3.14, 1.77, 1.769,
    1.769, 1.735, 3.02, 1.537, 1.8212, 2.28,
    37.684, 23.319, 28.272, 24.439, 67.58, 6.2082, 4.676, 7.802, 2.74, 8831913.245, 1.857, 5.35, 4.184,
    5.593, 5.344, 5.316, 631.9298, 73.46, 1.65625, 2.843,
    4.05, 21.127, 4.158, 230.763, 13.853, 161.48, 570.502, 90.473, 94.728, 6.43, 272.849, 3.306, 3.54,
    13407.84, 3.9756, 63232.8695, 46.545, 14.043, 2773.168, 2708.062,
    1.848, 1.8394, 1.86, 1.856, 1.86, 1.525, 1.86, 1.84, 1.822, 2.11, 1.802, 1.86, 1.805, 1.78, 1.847,
    1.808, 1.78,
    1.78, 2.1948, 1.79, 1.835, 1.484,
    1.845, 1.746, 1.85, 1.957, 1.846,
    1.848, 1.8394, 1.86, 1.856, 1.86,
    1.81, 1.7915, 1.815, 1.81, 1.809,
    40468, 1.52, 1.853, 1.861, 1.85447,
    1.8184, 1.8468, 1.527, 1.52, 1.848,
    20.02, 0.0246, 17.802, 17.45, 2.64,
    0.0837, 0.00342, 23.2356, 3.328, 1.81,
    1069.16, 35.746, 2.426, 1.48, 13.04,
    37.684, 23.319, 28.272, 24.439, 67.58,
    1.8354, 1.8362,
    1.955, 1.796, 1.47, 1.838, 1.85,
    1.812, 0.001748, 1.815, 1.809, 1.816,
    78.439, 9.002, 32.852, 17.05, 43.18
]

# Text Classification Data source code size (CSV)
file_sizes_classification = [
    1.85, 1.853, 1.846, 1.919, 1.92,
    1.834,
    0,
    2.48, 1.84, 1.864, 1.847, 1.85,
    1.882, 1.854,
    44.48, 2.8575, 50.975, 3.973, 4.91,
    1917.48, 1.85, 1.85, 1664.48, 1.85,
    0,
    37.684, 23.319, 28.272, 24.439, 67.58,
    1.8423, 1.88, 1.895, 2.6909, 1.882,
    12.13, 1.857,
    1.85, 1.853, 1.846, 1.919, 1.92,
    5.822, 8.68, 1.834, 0.2422, 0.902,
    1.917, 1.8496, 1.8842, 1.887, 1.885,
    6.39,
    1.85, 0.386, 0.1455,
    0,
    1.48, 1.8793, 1.646, 1.85,
    1.841, 1.48, 1.8374, 1.88
]

# Adjustable parameters
bin_size = 20
use_log_scale = True
small_constant = 1e-10  # Small constant to avoid log(0)

# Plotting
plt.figure(figsize=(15, 6))

# Plot for Text Generation
plt.subplot(1, 2, 1)
if use_log_scale:
    log_file_sizes_gen = np.log10(np.array(file_sizes_generation) + small_constant)
    log_file_sizes_gen = log_file_sizes_gen[np.isfinite(log_file_sizes_gen)]  # Remove NaN, -inf, inf
    plt.hist(log_file_sizes_gen, bins=bin_size, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel('Log(File Size) - Generation')
else:
    plt.hist(file_sizes_generation, bins=bin_size, color='blue', edgecolor='black', alpha=0.7)
    plt.xlabel('File Size - Generation')
plt.ylabel('Frequency')
plt.title('Distribution of File Sizes - Text Generation')
plt.grid(True)

# Plot for Text Classification
plt.subplot(1, 2, 2)
if use_log_scale:
    log_file_sizes_class = np.log10(np.array(file_sizes_classification) + small_constant)
    log_file_sizes_class = log_file_sizes_class[np.isfinite(log_file_sizes_class)]  # Remove NaN, -inf, inf
    plt.hist(log_file_sizes_class, bins=bin_size, color='green', edgecolor='black', alpha=0.7)
    plt.xlabel('Log(File Size) - Classification')
else:
    plt.hist(file_sizes_classification, bins=bin_size, color='green', edgecolor='black', alpha=0.7)
    plt.xlabel('File Size - Classification')
plt.ylabel('Frequency')
plt.title('Distribution of File Sizes - Text Classification')
plt.grid(True)

# Adjust layout
plt.tight_layout()
plt.show()

# %% [markdown]
# Overall, My analysis supports the claim that there are more ML applications for Text Generation models. However, ease of development cannot be conclusively determined based on source code size alone but overall review of the model.

# %% [markdown]
# 5. what other analysis could be useful to add?

# %% [markdown]
# 1. Other Programming Language Exploration: Exploring JAVASCRIPT, CURL and other programming language and libraries in analyzing the data can be significantly helpful.
#
# 2. Comparison of Largest and Smallest ML Apps: Identifying the largest and smallest apps in each category analysis and compare their characteristics. This could help in understanding the broad diversity in the complexity of ML applications within each model type.
